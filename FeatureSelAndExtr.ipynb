# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

import seaborn as sns

#file = pd.read_excel ('./Data/Data_Collection_missing.xlsx')
file = pd.read_excel ('./Data/Data_Collection.xlsx')

# %%
def draw_missing_data_table(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
df = pd.DataFrame(file)
draw_missing_data_table(df)
#df
# Out:
#                        Total   Percent
# EU Emigration            177  0.808219
# EU Imgration             177  0.808219
# Imigration               163  0.744292
# Emigration               163  0.744292
# Pop. Growth rate           1  0.004566
# Population growth all      1  0.004566
# Migration rate             1  0.004566
# Population growth          1  0.004566
# population                 0  0.000000
# No births female           0  0.000000
# Population change          0  0.000000
# No Briths E&W              0  0.000000
# No Births NI               0  0.000000
# No Births S                0  0.000000
# No Births All              0  0.000000
# Fertility Rates %          0  0.000000
# No births male             0  0.000000
# All Deaths                 0  0.000000
# No deaths EW               0  0.000000
# No deaths NI               0  0.000000
# No deaths S                0  0.000000
# Births_Deaths              0  0.000000
# Mortality rate             0  0.000000
# ...

# %%
#df.describe()
#df.dtypes

# %%
cols = df.columns
plt.style.use('classic')
colours = ['blue', 'yellow'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %%
#df.drop(df.index[3:5])

# %%
df.drop(df[pd.isnull(df['EU Imgration'])].index, inplace=True)

# %%
#df

# %%
cols = df.columns
plt.style.use('classic')
colours = ['blue', 'yellow'] # specify the colours - yellow is missing. blue is not missing.
#sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %%
df.drop(df[pd.isnull(df['EU Imgration'])].index, inplace=True)

df.drop(df[pd.isnull(df['Population growth'])].index, inplace=True)

# %%
#df

# %%
cols = df.columns

colours = ['blue', 'yellow'] # specify the colours - yellow is missing. blue is not missing.
#sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %%
#df.drop('EU Imgration', axis=1, inplace=True)
#df.drop('EU Emigration', axis=1, inplace=True)
df.drop('Imigration', axis=1, inplace=True)
df.drop('Emigration', axis=1, inplace=True)

# %%
cols = df.columns
plt.style.use('classic')
colours = ['blue', 'yellow'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %%
df['BitrhsMinusDeaths'] = df['No Births All'] + df['All Deaths']

# %%
draw_missing_data_table(df)
#df
# Out:
#                        Total  Percent
# Population growth all      0      0.0
# No deaths NI               0      0.0
# population                 0      0.0
# Population change          0      0.0
# No Briths E&W              0      0.0
# No Births NI               0      0.0
# No Births S                0      0.0
# No Births All              0      0.0
# Fertility Rates %          0      0.0
# No births male             0      0.0
# No births female           0      0.0
# No deaths EW               0      0.0
# No deaths S                0      0.0
# Pop. Growth rate           0      0.0
# All Deaths                 0      0.0
# Births_Deaths              0      0.0
# Mortality rate             0      0.0
# No deaths male             0      0.0
# No deaths female           0      0.0
# Migration                  0      0.0
# Migration rate             0      0.0
# EU Imgration               0      0.0
# EU Emigration              0      0.0
# Population growth          0      0.0
# ...

# %%
df.to_excel('./Data/subset1.xlsx')
