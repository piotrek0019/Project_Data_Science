# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns


import statsmodels.api as sm

from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale
from sklearn import preprocessing
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import PCA

file = pd.read_excel ('./Data/subset1.xlsx')


df = pd.DataFrame(file, columns=file.columns)

# %%
df.drop(df[pd.isnull(df['EU_Imgration'])].index, inplace=True)

# %%
df.drop('year', axis=1, inplace=True)
df.drop('id', axis=1, inplace=True)
df.drop('Population_growth_all', axis=1, inplace=True)
df.drop('Pop._Growth_rate', axis=1, inplace=True)
df.drop('Population_change', axis=1, inplace=True)
df.drop('Mortality_rate', axis=1, inplace=True)
df.drop('Fertility_Rates_%', axis=1, inplace=True)
df.drop('Births_Deaths', axis=1, inplace=True)

# %%
corr = df.corr()
corr.iloc[:,17:18]
# Out:
#                    Population_growth
# population                  0.928299
# No_Briths_E_W               0.576039
# No_Births_NI               -0.525631
# No_Births_S                -0.718065
# No_Births_All               0.444334
# No_births_male              0.436310
# No_births_female            0.452286
# No_deaths_EW               -0.929386
# No_deaths_NI               -0.838130
# No_deaths_S                -0.909024
# All_Deaths                 -0.930235
# No_deaths_male             -0.933309
# No_deaths_female           -0.856813
# Migration                   0.912909
# Migration_rate              0.902112
# EU_Imgration                0.933731
# EU_Emigration               0.868951
# Population_growth           1.000000

# %%
X = df.drop('Population_growth',1 )
Y = df['Population_growth']

# %%
sfs = SFS(LinearRegression(),
         k_features=11,
          forward=True,
          floating=False,
          scoring = 'r2',
          cv = 0)

sfs.fit(X,Y)
sfs.k_feature_names_
# Out:
# ('population',
#  'No_Briths_E_W',
#  'No_Births_NI',
#  'No_Births_S',
#  'No_births_male',
#  'No_deaths_EW',
#  'No_deaths_NI',
#  'No_deaths_S',
#  'Migration',
#  'Migration_rate',
#  'EU_Imgration')

# %%
x = pd.DataFrame(file, columns=[
 'population',
 'No_Briths_E_W',
 'No_Births_NI',
 'No_Births_S',
 'No_births_male',
 'No_deaths_EW',
 'No_deaths_NI',
 'No_deaths_S',
 'Migration',
 'Migration_rate',
 'EU_Imgration',])
"""
x = pd.DataFrame(file, columns=[
    'population', 
    'No_Briths_E_W', 
    'No_Births_All', 
    'No_births_male', 
    'No_births_female',
    'Births_Deaths',  
    'Migration', 
    'EU_Imgration', 
    'EU_Emigration'])
"""
y = pd.DataFrame(file, columns=['Population_growth'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0, shuffle=False)
x_train
# Out:
#     population  No_Briths_E_W  No_Births_NI  No_Births_S  No_births_male  \
# 0     65423047         695233         24394        56725          398371
# 1     64984018         698512         24277        56014          399599
# 2     64525312         729674         25269        58027          417058
# 3     64021919         723913         25273        58590          413910
# 4     63459808         723165         25315        58791          413755
# 5     62828616         706248         24910        59046          405099
# 6     62145097         708711         25631        60041          406737
# 7     61455162         690013         24451        57781          396698
# 8     60821356         669601         23272        55690          382912
# 9     60287954         645835         22328        54386          370024
# 10    59872753         639721         22318        53957          367586
# 11    59561432         621469         21648        52432          356578
# 12    59326294         596122         21385        51270          343155
# 13    59124288         594634         21962        52527          342709
# 14    58923309         604441         21512        53076          347941
# 15    58715854         621872         22957        55147          359444
# 16    58509974         635901         23668        57319          367457
# 17    58307313         643095         24087        59440          372418
# 18    58113557         649485         24382        59296          376395
# 19    57932453         648138         23693        60051          375133
# 20    57763378         664726         24098        61656          385081
# 21    57602284         673467         24722        63337          390724
# 22    57446037         689656         25354        65789          400228
# 23    57290785         699217         26028        67024          406253
# 24    57134391         706140         26251        65973          408747
# 25    56974297         687725         25831        63480          398192
# 26    56812757         693577         27514        66212          403145
# 27    56658270         681511         27653        66241          397790
#
#     No_deaths_EW  No_deaths_NI  No_deaths_S  Migration  Migration_rate  \
# 0         501424         14678        54239     313000        0.004784
# 1         506790         14968        54700     209000        0.003216
# 2         499331         14756        54937     177000        0.002743
# 3         484367         14204        53661     215000        0.003358
# 4         493242         14457        53967     252000        0.003971
# 5         491348         14413        53856     199000        0.003167
# 6         509090         14907        55700     163000        0.002623
# 7         504052         14649        55986     233000        0.003791
# 8         502599         14532        55093     198000        0.003255
# 9         512993         14224        55747     206000        0.003417
# 10        514250         14354        56187     245000        0.004092
# 11        539151         14462        58472     148000        0.002485
# 12        535356         14586        58103     153000        0.002579
# 13        532498         14513        57382     172000        0.002909
# 14        537877         14903        57799     158000        0.002681
# 15        553532         15663        60281     163000        0.002776
# 16        553435         14993        59164     140000        0.002393
# 17        558052         14971        59494      48000        0.000823
# 18        563007         15218        60654      54000        0.000929
# 19        565902         15310        60500      76000        0.001312
# 20        551780         15114        59328      77000        0.001333
# 21        578512         15633        64049          0        0.000000
# 22        558313         14988        60937     -13000       -0.000226
# 23        570044         15096        61041      44000        0.000768
# 24        564846         15426        61527      36000        0.000630
# 25        576872         15844        65017      45000        0.000790
# 26        571408         15813        61957     -21000       -0.000370
# 27        566994         15334        62014       2000        0.000035
#
#     EU_Imgration
# 0         269000
# 1         264000
# 2         201000
# 3         158000
# 4         174000
# 5         176000
# 6         167000
# 7         198000
# 8         195000
# 9         170000
# 10        151000
# 11        127000
# 12         66000
# 13         61000
# 14         58000
# 15         63000
# 16         66000
# 17         82000
# 18         71000
# 19         72000
# 20         61000
# 21         50000
# 22         44000
# 23         44000
# 24         53000
# 25         37000
# 26         31000
# 27         27000

# %%
scaler = preprocessing.StandardScaler()

sx_train = scaler.fit_transform(x_train)
sx_test = scaler.fit_transform(x_test)

# %%
lr = LinearRegression()
lr.fit(sx_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(sx_test)

# %%
#mean square error
np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 82784.4099950444

# %%
#compare predicted numbers with actual numbes 
check = np.column_stack((y_test, y_pred))
pd.DataFrame(check, columns=['actual', 'predicted'])
sns.regplot(y_test, y_pred)
lr.score(sx_test, y_test)
# Out:
# 0.640245429181789

# %%
lrN = GaussianNB().fit(sx_train, np.hstack(y_train.values))

# %%
y_pred_n = lrN.predict(sx_test)

# %%
#compare predicted numbers with actual numbes 
check = np.column_stack((y_test, y_pred_n))
pd.DataFrame(check, columns=['actual', 'predicted'])
# Out:
#     actual  predicted
# 0   192565     190088
# 1    37189        198
# 2   131070     133561
# 3   470544     506383
# 4   345585     374339
# 5   121483     142105
# 6   117125     103332
# 7   376205     374339
# 8    64995     -24273
# 9   137864     142105
# 10  133063     190088
# 11  166170     229296
# 12  -44105      14775

# %%
sns.regplot(y_test, y_pred_n)

# %%
np.sqrt(metrics.mean_squared_error(y_test, y_pred_n))
# Out:
# 41880.099572837324

# %%
#Standardizing the features
sX = scaler.fit_transform(X)
#dimension reduction 16D into 4D
pca = PCA(n_components=4).fit_transform(sX)

# %%
x_train, x_test, y_train, y_test = train_test_split(pca, y, test_size=0.3, random_state=0)

# %%
#linear regression after dimension reduction using PCA
lrP = LinearRegression().fit(x_train, y_train)

yP_pred = lrP.predict(x_test)
#Root Mean Squared Error
np.sqrt(metrics.mean_squared_error(y_test, yP_pred))
# Out:
# 47725.220412818235

# %%
#seeking the best random_state parameter for train_test_split
lr3 = LinearRegression()
sqrt = 0
best_sqrt = 0
best_rand_state = 0

for n in range(100):
    x_train, x_test, y_train, y_test = train_test_split(pca, y, test_size=0.2, random_state=n)
    
   
    
    lr3.fit(x_train, y_train)
    
    y_pred = lr3.predict(x_test)
    
    
    
    sqrt = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    
    if n < 1:
        best_sqrt = sqrt

    if sqrt < best_sqrt:
        best_sqrt = sqrt
        best_rand_state = n
        
print("The best sqrt is: ", best_sqrt)
print("The best random_state is: ", best_rand_state)
# Out:
# The best sqrt is:  28408.562988860685
# The best random_state is:  77
